# %% [markdown]
# # ASSIGNEMENT NO 11 (Text Mining)

# %% [markdown]
# ## <font color ="red"> Extract reviews of any product from ecommerce website like amazon

# %%
import numpy as np
import pandas as pd

# %%
pip install autoscraper
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=ab79afeafc343e663e9644388c5a1048290321b19d01337eeb79c78c7f225973
#   Stored in directory: c:\users\aksha\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from autoscraper import AutoScraper

# %%
amazon_url = "https://www.amazon.in/boAt-Wave-Call-Dedicated-Multi-Sport/product-reviews/B0B5B6PQCT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"

wanted_list = ["pritam saha","Good But touch screen not so smooth and mainly blootooth connection issue"]

# %%
scraper = AutoScraper()
result = scraper.build(amazon_url,wanted_list)
print(result)
# Out:
# ['AV', 'Placeholder', 'pritam saha', 'Umesh', 'Hemant Kumar Ravi', 'Lalit Kumar', 'Shalini', 'Ana mary', 'Ramesh Salokhe', 'Punith M', "Pros and Cons:1) Watch looks good and feels premium because of the metal body..2) All the features mentioned about the watch (like call, SPO2, heart rate etc) actually works good except the sensors which gives results on any soft surfaces like any other watch in this range..Note: Don't trust on these for medical purposes...", 'Good But touch screen not so smooth and mainly blootooth connection issue', 'Not work music function and not shortly connect to mobile through app.', 'A very good product in mid range. Calling features working well.', 'I loved the display area, it gives a royal view. And in the strap , instead of the black colour buckle, it could be the same in the display, kind of silver, will be more attractive incase in that colour.', "[Update: Sept 29] boAt seems to have heard the feedback 😀 and updated the watch faces. Now there are a few 
# ...

# %%
scraper.get_result_similar(amazon_url,grouped=True)
# Out:
# {'rule_ioc2': ['AV',
#   'Placeholder',
#   'pritam saha',
#   'Umesh',
#   'Hemant Kumar Ravi',
#   'Lalit Kumar',
#   'Shalini',
#   'Ana mary',
#   'Ramesh Salokhe',
#   'Punith M'],
#  'rule_cm7n': ["Pros and Cons:1) Watch looks good and feels premium because of the metal body..2) All the features mentioned about the watch (like call, SPO2, heart rate etc) actually works good except the sensors which gives results on any soft surfaces like any other watch in this range..Note: Don't trust on these for medical purposes...",
#   'Good But touch screen not so smooth and mainly blootooth connection issue',
#   'Not work music function and not shortly connect to mobile through app.',
#   'A very good product in mid range. Calling features working well.',
#   'I loved the display area, it gives a royal view. And in the strap , instead of the black colour buckle, it could be the same in the display, kind of silver, will be more attractive incase in that colour.'],
# ...

# %%
scraper.set_rule_aliases({"rule_crep":"Review"})
scraper.keep_rules(["rule_crep"])
scraper.save("amazon-search")

# %%
results = scraper.get_result_similar("https://www.amazon.in/boAt-Wave-Call-Dedicated-Multi-Sport/product-reviews/B0B5B6PQCT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews",group_by_alias=True)
results["Review"]
# Out:
# ["[Update: Sept 29] boAt seems to have heard the feedback 😀 and updated the watch faces. Now there are a few good ones to pick but a slight improvement over the ones the watch earlier had. Bit Impressed. Added one star for it.Not a very polished product. The fonts are tacky and look ugly in the watch for notification text and caller name text. The watch faces are a lazy design job. No point having 150 watch faces if only 10-20 are good or usable. Rest are useless.[UPDATE: Oct 11] boAt seems to be on a smartwatch launch spree. And thanks to that, they are constantly updating the phone app and the watch faces. Now you have many good looking watch faces to choose from. So overall, still the Smartwatch UI needs work. But atleast you have good watch faces.Good:- Screen quality- Battery life- Looks and the metallic frame- Call clarity- BT calling at the price- Reasonably accurate sensorsBad:- The UI, fonts - they are all very ugly and tacky. They could have tried to give the Chinese softwa
# ...

# %%
afinn = pd.read_csv( "C:\\Users\\aksha\\Downloads\\Afinn.csv",sep=",", encoding="ISO-8859-1")

# %%
afinn
# Out:
#            word  value
# 0       abandon     -2
# 1     abandoned     -2
# 2      abandons     -2
# 3      abducted     -2
# 4     abduction     -2
# ...         ...    ...
# 2472      yucky     -2
# 2473      yummy      3
# 2474     zealot     -2
# 2475    zealots     -2
# 2476    zealous      2
#
# [2477 rows x 2 columns]

# %%
data = results["Review"]

# %%
import pandas as pd
import numpy as np
import string
import spacy

from matplotlib.pyplot import imread
from matplotlib import pyplot as plt
from wordcloud import WordCloud
# %matplotlib inline

# %%
from nltk import tokenize
sentences = tokenize.sent_tokenize(" ".join(data))
sentences
# Out:
# ['[Update: Sept 29] boAt seems to have heard the feedback 😀 and updated the watch faces.',
#  'Now there are a few good ones to pick but a slight improvement over the ones the watch earlier had.',
#  'Bit Impressed.',
#  'Added one star for it.Not a very polished product.',
#  'The fonts are tacky and look ugly in the watch for notification text and caller name text.',
#  'The watch faces are a lazy design job.',
#  'No point having 150 watch faces if only 10-20 are good or usable.',
#  'Rest are useless.',
#  '[UPDATE: Oct 11] boAt seems to be on a smartwatch launch spree.',
#  'And thanks to that, they are constantly updating the phone app and the watch faces.',
#  'Now you have many good looking watch faces to choose from.',
#  'So overall, still the Smartwatch UI needs work.',
# ...

# %%
from nltk import tokenize
sentences = tokenize.sent_tokenize(" ".join(data))
sentences
# Out:
# ['[Update: Sept 29] boAt seems to have heard the feedback 😀 and updated the watch faces.',
#  'Now there are a few good ones to pick but a slight improvement over the ones the watch earlier had.',
#  'Bit Impressed.',
#  'Added one star for it.Not a very polished product.',
#  'The fonts are tacky and look ugly in the watch for notification text and caller name text.',
#  'The watch faces are a lazy design job.',
#  'No point having 150 watch faces if only 10-20 are good or usable.',
#  'Rest are useless.',
#  '[UPDATE: Oct 11] boAt seems to be on a smartwatch launch spree.',
#  'And thanks to that, they are constantly updating the phone app and the watch faces.',
#  'Now you have many good looking watch faces to choose from.',
#  'So overall, still the Smartwatch UI needs work.',
# ...

# %%
review_df = pd.DataFrame(sentences, columns=["review_comments"])
review_df
# Out:
#                                       review_comments
# 0   [Update: Sept 29] boAt seems to have heard the...
# 1   Now there are a few good ones to pick but a sl...
# 2                                      Bit Impressed.
# 3   Added one star for it.Not a very polished prod...
# 4   The fonts are tacky and look ugly in the watch...
# 5              The watch faces are a lazy design job.
# 6   No point having 150 watch faces if only 10-20 ...
# 7                                   Rest are useless.
# 8   [UPDATE: Oct 11] boAt seems to be on a smartwa...
# 9   And thanks to that, they are constantly updati...
# 10  Now you have many good looking watch faces to ...
# 11    So overall, still the Smartwatch UI needs work.
# 12  But atleast you have good watch faces.Good:- S...
# 13  They could have tried to give the Chinese soft...
# 14     But it is a clearly lazy job by the tech team.
# 15  A copy paste job to be precise of getting an o...
# ...

# %%
affinity_score = afinn.set_index("word")["value"].to_dict()
affinity_score
# Out:
# {'abandon': -2,
#  'abandoned': -2,
#  'abandons': -2,
#  'abducted': -2,
#  'abduction': -2,
#  'abductions': -2,
#  'abhor': -3,
#  'abhorred': -3,
#  'abhorrent': -3,
#  'abhors': -3,
#  'abilities': 2,
#  'ability': 2,
#  'aboard': 1,
#  'absentee': -1,
#  'absentees': -1,
#  'absolve': 2,
#  'absolved': 2,
#  'absolves': 2,
#  'absolving': 2,
#  'absorbed': 1,
#  'abuse': -3,
#  'abused': -3,
#  'abuses': -3,
#  'abusive': -3,
#  'accept': 1,
#  'accepted': 1,
#  'accepting': 1,
#  'accepts': 1,
#  'accident': -2,
#  'accidental': -2,
#  'accidentally': -2,
#  'accidents': -2,
#  'accomplish': 2,
#  'accomplished': 2,
#  'accomplishes': 2,
#  'accusation': -2,
#  'accusations': -2,
#  'accuse': -2,
#  'accused': -2,
#  'accuses': -2,
#  'accusing': -2,
#  'ache': -2,
#  'achievable': 1,
#  'aching': -2,
#  'acquit': 2,
#  'acquits': 2,
#  'acquitted': 2,
#  'acquitting': 2,
#  'acrimonious': -3,
#  'active': 1,
#  'adequate': 1,
#  'admire': 3,
#  'admired': 3,
#  'admires': 3,
# ...

# %%
nlp = spacy.load("en_core_web_sm")
sentiment_lexicon = affinity_score

def calculate_sentiment(text: str=None):
    sent_score=0
    if text :
        sentence = nlp(text)
        for word in sentence:
             sent_score += sentiment_lexicon.get(word.lemma_, 0)
    return sent_score

calculate_sentiment(text = "amazing")
# Out:
# 4

# %%
review_df["sentiment_value"] = review_df["review_comments"].apply(calculate_sentiment)

# %%
review_df["word_count"] = review_df["review_comments"].str.split().apply(len)
review_df["word_count"].head(10)
# Out:
# 0    16
# 1    20
# 2     2
# 3     9
# 4    17
# 5     8
# 6    13
# 7     3
# 8    12
# 9    15
# Name: word_count, dtype: int64

# %%
review_df.sort_values(by="sentiment_value").tail(10)
# Out:
#                                       review_comments  sentiment_value  \
# 6   No point having 150 watch faces if only 10-20 ...                2
# 18  Noise Colorfit Pulse Go Buzz is cheaper and be...                2
# 10  Now you have many good looking watch faces to ...                3
# 22                  A very good product in mid range.                3
# 25   I loved the display area, it gives a royal view.                3
# 1   Now there are a few good ones to pick but a sl...                5
# 19  Your products are good, but the UI and design ...                6
# 27  The product is good but could be even better C...                7
# 17  BoAt doesn't have a good team of designers and...               13
# 21  Pros and Cons:1) Watch looks good and feels pr...               18
#
#     word_count
# 6           13
# 18          82
# 10          11
# 22           7
# 25          10
# 1           20
# 19          24
# 27          16
# 17          46
# 21          83

# %%
review_df['sentiment_value'].describe()
# Out:
# count    28.000000
# mean      2.142857
# std       4.436501
# min      -3.000000
# 25%       0.000000
# 50%       0.000000
# 75%       3.000000
# max      18.000000
# Name: sentiment_value, dtype: float64

# %%
import seaborn as sns
sns.distplot(review_df["sentiment_value"])
# Out:
# C:\Users\aksha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sentiment_value', ylabel='Density'>

# %%
review_df.plot.scatter(x='word_count', y='sentiment_value', figsize=(8,8), title='Sentence sentiment value to sentence word count')
# Out:
# <AxesSubplot:title={'center':'Sentence sentiment value to sentence word count'}, xlabel='word_count', ylabel='sentiment_value'>

# %%
review_df
# Out:
#                                       review_comments  sentiment_value  \
# 0   [Update: Sept 29] boAt seems to have heard the...                0
# 1   Now there are a few good ones to pick but a sl...                5
# 2                                      Bit Impressed.                0
# 3   Added one star for it.Not a very polished prod...                0
# 4   The fonts are tacky and look ugly in the watch...               -3
# 5              The watch faces are a lazy design job.               -1
# 6   No point having 150 watch faces if only 10-20 ...                2
# 7                                   Rest are useless.               -2
# 8   [UPDATE: Oct 11] boAt seems to be on a smartwa...                0
# 9   And thanks to that, they are constantly updati...                2
# 10  Now you have many good looking watch faces to ...                3
# 11    So overall, still the Smartwatch UI needs work.                0
# ...
